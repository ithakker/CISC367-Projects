# %% [markdown]
# # Ishaan Thakker - CORGIS Billionaire Dataset Rework

# %% [markdown]
# Using the data from the billionaire dataset on CORGIS, I will be reworking this data to one that I found which is what I will be using to guide me in creating a new dataset.
#
# [Reference Dataset](https://github.com/civisanalytics/potato/tree/master/data/billion)

# %%
#Importing
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("billionaire-corgis.csv")
df.head()
# Out:
#                             name   age  children marital-status      country  \
# 0  charlene-de-carvalho-heineken  60.0         5        Married  Netherlands
# 1                 beny-steinmetz  58.0         4        Married       Israel
# 2                   lee-shau-kee  86.0         5       Divorced    Hong Kong
# 3                  david-thomson  57.0         4       Divorced       Canada
# 4            bidzina-ivanishvili  58.0         4        Married      Georgia
#
#    gender         industry     source  net-worth
# 0  Female  Food & Beverage  Inherited        9.8
# 1    Male  Metals & Mining  Self-made        2.7
# 2    Male      Real Estate  Self-made       22.1
# 3    Male            Media  Inherited       24.3
# 4    Male      Diversified  Self-made        5.2

# %%
existing = pd.read_csv("References/billionaires-corgis.csv")
existing.head()
# Out:
#          Bill Gates  1  1996  1975           Microsoft  founder  \
# 0        Bill Gates  1  2001  1975           Microsoft  founder
# 1        Bill Gates  1  2014  1975           Microsoft  founder
# 2    Warren Buffett  2  1996  1962  Berkshire Hathaway  founder
# 3    Warren Buffett  2  2001  1962  Berkshire Hathaway  founder
# 4  Carlos Slim Helu  2  2014  1990              Telmex  founder
#
#           Software            new  40  male  ... 8100000000000.0  \
# 0         Software            new  45  male  ...    1.060000e+13
# 1         Software            new  58  male  ...    0.000000e+00
# 2          Finance            new  65  male  ...    8.100000e+12
# 3          Finance            new  70  male  ...    1.060000e+13
# 4   Communications  privatization  74  male  ...    0.000000e+00
#
#    North America       founder non-finance  18.5         New Sectors   True  \
# 0  North America       founder non-finance  58.7         New Sectors   True
# 1  North America       founder non-finance  76.0         New Sectors   True
# 2  North America       founder non-finance  15.0      Traded Sectors   True
# 3  North America       founder non-finance  32.3      Traded Sectors   True
# 4  Latin America  privatized and resources  72.0  Non-Traded Sectors  False
#
#    Technology-Computer  not inherited True.1  False
# 0  Technology-Computer  not inherited   True  False
# 1  Technology-Computer  not inherited   True  False
# 2             Consumer  not inherited   True  False
# 3             Consumer  not inherited   True  False
# 4                Media  not inherited   True  False
#
# [5 rows x 22 columns]

# %%
#Renaming columns to be visually better
df.rename(columns = {"name":"Name", "age":"Age", "children":"Children", "marital-status":"Married?",
                     "country":"Country", "gender":"Gender", "industry":"Industry", "source":"Source",
                     "net-worth":"Net-Worth"}, inplace = True)
df.columns
# Out:
# Index(['Name', 'Age', 'Children', 'Married?', 'Country', 'Gender', 'Industry',
#        'Source', 'Net-Worth'],
#       dtype='object')

# %%
#Before formatting data
df.head()
# Out:
#                             Name   Age  Children  Married?      Country  \
# 0  charlene-de-carvalho-heineken  60.0         5   Married  Netherlands
# 1                 beny-steinmetz  58.0         4   Married       Israel
# 2                   lee-shau-kee  86.0         5  Divorced    Hong Kong
# 3                  david-thomson  57.0         4  Divorced       Canada
# 4            bidzina-ivanishvili  58.0         4   Married      Georgia
#
#    Gender         Industry     Source  Net-Worth
# 0  Female  Food & Beverage  Inherited        9.8
# 1    Male  Metals & Mining  Self-made        2.7
# 2    Male      Real Estate  Self-made       22.1
# 3    Male            Media  Inherited       24.3
# 4    Male      Diversified  Self-made        5.2

# %%
# After formatting data
df['Married?'] = df['Married?'].replace(['Married'], 'Yes')
df['Married?'] = df['Married?'].replace(['Divorced'], 'No')
df['Name'] = df['Name'].str.title()
df['Name'] = df['Name'].replace('-', ' ', regex = True)
df.head()
# Out:
#                             Name   Age  Children Married?      Country  \
# 0  Charlene De Carvalho Heineken  60.0         5      Yes  Netherlands
# 1                 Beny Steinmetz  58.0         4      Yes       Israel
# 2                   Lee Shau Kee  86.0         5       No    Hong Kong
# 3                  David Thomson  57.0         4       No       Canada
# 4            Bidzina Ivanishvili  58.0         4      Yes      Georgia
#
#    Gender         Industry     Source  Net-Worth
# 0  Female  Food & Beverage  Inherited        9.8
# 1    Male  Metals & Mining  Self-made        2.7
# 2    Male      Real Estate  Self-made       22.1
# 3    Male            Media  Inherited       24.3
# 4    Male      Diversified  Self-made        5.2

# %%
#Adding most important values to new dataframe
new = pd.DataFrame()
#new = pd.concat([df, existing])
new['Name'] = existing['Bill Gates']
new['Age'] = existing['40']
new.replace(0, np.nan, inplace=True)
new['Gender'] = existing['male']
new['Net_Worth'] = existing['18.5']
new['Region'] = existing['North America']
new['Company'] = existing['Microsoft']


new = new.drop(columns = '')


#Sorting the data by net worth so names are not repeating, makes for easier data manipulation
new = new.sort_values(by = ["Net_Worth"], ascending = False)

new
# Out:
#                             Name   Age          Gender  Net_Worth  \
# 1                     Bill Gates  58.0            male       76.0
# 4               Carlos Slim Helu  74.0            male       72.0
# 7                 Amancio Ortega  77.0            male       64.0
# 0                     Bill Gates  45.0            male       58.7
# 10                Warren Buffett  83.0            male       58.2
# ...                          ...   ...             ...        ...
# 1437             Jerome Kohlberg  75.0            male        1.0
# 1436                James France  56.0            male        1.0
# 1435             Jacques Servier   NaN            male        1.0
# 1434  Jacob and Yehudith Richter   NaN  married couple        1.0
# 2612                 Zhu Wenchen  48.0            male        1.0
#
#                         Region                      Company
# 1                North America                    Microsoft
# 4                Latin America                       Telmex
# 7                       Europe                         Zara
# 0                North America                    Microsoft
# 10               North America           Berkshire Hathaway
# ...                        ...                          ...
# 1437             North America  Kohberg Kravis Roberts & Co
# 1436             North America                       NASCAR
# 1435                    Europe         Laboratories Servier
# 1434  Middle East/North Africa                      Medinol
# 2612                 East Asia   Furen Pharmaceutical Group
#
# [2613 rows x 6 columns]

# %%
new.to_csv("billionaires - corgis.csv", index = True)
